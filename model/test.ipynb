# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from PIL import Image
import os

# %%
img = cv2.imread('dataset/Train/11/00011_00000_00010.png')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img.shape
# Out:
# (28, 34, 3)

# %%
image = Image.open('dataset/Train/11/00011_00000_00010.png')
image_detail = np.array(image)
image_detail.shape
# Out:
# (28, 34, 3)

# %%
ig = image.resize((224,224))
plt.imshow(ig)
ig_detail = np.array(ig)
ig_detail.shape
# Out:
# (224, 224, 3)

# %%
original_height, original_width = img.shape[:2]
factor = 10
resized_image = cv2.resize(img, (220, 220), interpolation=cv2.INTER_CUBIC )
resized_image2 = cv2.resize(img, (220, 220) )

cv2.imwrite('resized_image.jpg',resized_image)
# Out:
# True

# %%
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(resized_image2, cv2.COLOR_BGR2RGB))

# %%
resized_image.shape
# Out:
# (220, 220, 3)

# %%
original_image = cv2.imread('original_image.jpg',0)
original_height, original_width = original_image.shape[:2]
factor = 2
resized_image = cv2.resize(original_image, (int(original_height*factor), int(original_width*factor)), interpolation=cv2.INTER_CUBIC )

cv2.imwrite('resized_image.jpg',resized_image)
#fixed var name
